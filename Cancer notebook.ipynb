# %%
import pandas as pd #For DataFrames
import numpy as np #Mathmatical Operations
import seaborn as sns #Plotting
import matplotlib.pyplot as plt #Plotting
pd.set_option('display.max_columns',40) #show all the columns
sns.set(style="darkgrid") # make plot's background dark

# %% [markdown]
# ### Load the data

# %%
data = pd.read_csv("data.csv")

# %% [markdown]
# ### Show the first five rows

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### show the last five rows

# %%
data.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %% [markdown]
# ### we can notice that the all last column is NaN , so we will drop it

# %%
data.drop(columns=['Unnamed: 32','id'] , axis=0 , inplace=True)

# %%
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# ...

# %% [markdown]
# ### check the missing value

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# ### As we can see , there aren't missing values

# %% [markdown]
# ### we will display the columns's names

# %%
data.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# ### Now we will see values of diagnosis coulmn

# %%
data['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# #### we will show the countplot of diagnosis

# %%
sns.countplot(data.diagnosis)

# %%
data.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
#  that is mean 212 of peaple who has cancer , the cancer has spread to other parts of the body ,,
#  and 357 of them has B-cell lymphoma , this type of cancer forms in B cells (a type of immune system cell). B-cell lymphomas may be either indolent (slow-growing) or aggressive (fast-growing).

# %% [markdown]
# #### Now we will see the effect of diagnosis on the shape of the cell

# %%
plt.figure(figsize=(10,15))
plt.subplot(4,2,1)
sns.boxplot(data.radius_mean)
plt.subplot(4,2,2)
sns.boxplot(data.radius_se)
plt.subplot(4,2,3)
sns.boxplot(data.radius_worst)
plt.show()

# %% [markdown]
# ##### we notice that there are outliers , so we will find and drop them ,, and the range of radius_mean is from 0 to 22 , radius_se is from 0.1 to 0.8 , and radius_worst is from 0 to 27 , then the the worst situation in radius_worst

# %%
data[data['radius_mean']>25]
data[data['radius_se']>2.0]
data[data['radius_worst']>35]
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 461         M        27.42         26.27           186.9     2501.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 461           0.1084            0.1988          0.3635               0.1689
#
#      symmetry_mean  fractal_dimension_mean  radius_se  texture_se  \
# 461         0.2061                 0.05623      2.547       1.306
#
#      perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  \
# 461         18.65    542.2        0.00765         0.05374       0.08055
#
#      concave points_se  symmetry_se  fractal_dimension_se  radius_worst  \
# 461            0.02598      0.01697              0.004558         36.04
#
#      texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 461          31.37            251.2      4254.0            0.1357
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# ...

# %%
data.drop([461] , inplace=True)

# %% [markdown]
# #### check the texture

# %%
plt.figure(figsize=(10,15))
plt.subplot(4,2,1)
sns.boxplot(data.texture_mean)
plt.subplot(4,2,2)
sns.boxplot(data.texture_se)
plt.subplot(4,2,3)
sns.boxplot(data.texture_worst)
plt.show()

# %% [markdown]
# ##### we notice that there are outliers , so we will find and drop them ,, the range of texture_mean is from 0 to 30 , texture_se is from 0 to 2.5 , and texture_worst is from 10 to 42

# %%
data[data['texture_mean']>35]
data[data['texture_se']>3.5]
data[data['texture_worst']>45]
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 219         M        19.53         32.47           128.0     1223.0
# 259         M        15.53         33.56           103.7      744.9
# 265         M        20.73         31.12           135.7     1419.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 219          0.08420            0.1130          0.1145              0.06637
# 259          0.10630            0.1639          0.1751              0.08399
# 265          0.09469            0.1143          0.1367              0.08646
#
#      symmetry_mean  fractal_dimension_mean  radius_se  texture_se  \
# 219         0.1428                 0.05313     0.7392       1.321
# 259         0.2091                 0.06650     0.2419       1.278
# 265         0.1769                 0.05674     1.1720       1.617
#
#      perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  \
# ...

# %%
data.drop([219,259,265] , inplace=True)

# %% [markdown]
# #### check 	perimeter

# %%
plt.figure(figsize=(10,15))
plt.subplot(4,2,1)
sns.boxplot(data.perimeter_mean)
plt.subplot(4,2,2)
sns.boxplot(data.perimeter_se)
plt.subplot(4,2,3)
sns.boxplot(data.perimeter_worst)
plt.show()

# %% [markdown]
# #### we notice that there are outliers , so we will drop them ,, and the range of perimeter_mean is from 40 to 140 , perimeter_se is from 0 to 5.2 , and perimeter_worst is from 50 to 175

# %%
data[data['perimeter_mean']>160]
data[data['perimeter_se']>10]
data[data['perimeter_worst']>215]
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 180         M        27.22         21.87           182.1     2250.0
# 352         M        25.73         17.46           174.2     2010.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 180           0.1094            0.1914          0.2871               0.1878
# 352           0.1149            0.2363          0.3368               0.1913
#
#      symmetry_mean  fractal_dimension_mean  radius_se  texture_se  \
# 180         0.1800                 0.05770     0.8361      1.4810
# 352         0.1956                 0.06121     0.9948      0.8509
#
#      perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  \
# 180         5.820    128.7       0.004631         0.02537       0.03109
# 352         7.222    153.1       0.006369         0.04243       0.04266
#
#      concave points_se  symmetry_se  fractal_dimension_se  radius_worst  \
# ...

# %%
data.drop([180,352] , inplace=True)

# %% [markdown]
# #### Turn the diagnosis [M to 1 and B to 0]

# %%
data.diagnosis.replace(to_replace = dict(M = 1, B = 0), inplace = True)

# %% [markdown]
# #### Now It's time to split the datasets into three dataframes

# %%
mean_df =data.iloc[:, :11]
#drop the _mean 
mean_df.rename(columns=lambda x: x[:-5], inplace=True)
mean_df.head()
# Out:
#    diag  radius  texture  perimeter    area  smoothness  compactness  \
# 0     1   17.99    10.38     122.80  1001.0     0.11840      0.27760
# 1     1   20.57    17.77     132.90  1326.0     0.08474      0.07864
# 2     1   19.69    21.25     130.00  1203.0     0.10960      0.15990
# 3     1   11.42    20.38      77.58   386.1     0.14250      0.28390
# 4     1   20.29    14.34     135.10  1297.0     0.10030      0.13280
#
#    concavity  concave points  symmetry  fractal_dimension
# 0     0.3001         0.14710    0.2419            0.07871
# 1     0.0869         0.07017    0.1812            0.05667
# 2     0.1974         0.12790    0.2069            0.05999
# 3     0.2414         0.10520    0.2597            0.09744
# 4     0.1980         0.10430    0.1809            0.05883

# %% [markdown]
# ###### describe the df1

# %%
mean_df.describe()
# Out:
#              diag      radius     texture   perimeter         area  \
# count  563.000000  563.000000  563.000000  563.000000   563.000000
# mean     0.365897   14.036002   19.206146   91.331758   643.843694
# std      0.482109    3.398703    4.202906   23.406355   330.993611
# min      0.000000    6.981000    9.710000   43.790000   143.500000
# 25%      0.000000   11.685000   16.165000   75.015000   419.250000
# 50%      0.000000   13.280000   18.820000   85.980000   546.100000
# 75%      1.000000   15.740000   21.690000  103.500000   770.050000
# max      1.000000   28.110000   39.280000  188.500000  2499.000000
#
#        smoothness  compactness   concavity  concave points   symmetry  \
# count  563.000000   563.000000  563.000000      563.000000  563.00000
# mean     0.096290     0.103645    0.087235        0.048046    0.18112
# std      0.014082     0.052455    0.078029        0.037679    0.02746
# min      0.052630     0.019380    0.000000        0.000000    0.10600
# ...

# %% [markdown]
# ### see the violonplot of each column

# %%
plt.figure(figsize=(20,20))
plt.subplot(5,2,1)
sns.violinplot(x=mean_df["radius"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,2)
sns.violinplot(x=mean_df["texture"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,3)
sns.violinplot(x=mean_df["perimeter"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,4)
sns.violinplot(x=mean_df["area"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,5)
sns.violinplot(x=mean_df["smoothness"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,6)
sns.violinplot(x=mean_df["compactness"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,7)
sns.violinplot(x=mean_df["concavity"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,8)
sns.violinplot(x=mean_df["concave points"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,9)
sns.violinplot(x=mean_df["symmetry"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,10)
sns.violinplot(x=mean_df["fractal_dimension"])

# %%
se_df =data.iloc[:, 11:21]
#drop the_se
se_df.rename(columns=lambda x: x[:-3], inplace=True)
se_df.head()
# Out:
#    radius  texture  perimeter    area  smoothness  compactness  concavity  \
# 0  1.0950   0.9053      8.589  153.40    0.006399      0.04904    0.05373
# 1  0.5435   0.7339      3.398   74.08    0.005225      0.01308    0.01860
# 2  0.7456   0.7869      4.585   94.03    0.006150      0.04006    0.03832
# 3  0.4956   1.1560      3.445   27.23    0.009110      0.07458    0.05661
# 4  0.7572   0.7813      5.438   94.44    0.011490      0.02461    0.05688
#
#    concave points  symmetry  fractal_dimension
# 0         0.01587   0.03003           0.006193
# 1         0.01340   0.01389           0.003532
# 2         0.02058   0.02250           0.004571
# 3         0.01867   0.05963           0.009208
# 4         0.01885   0.01756           0.005115

# %%
se_df.describe()
# Out:
#            radius     texture   perimeter        area  smoothness  \
# count  563.000000  563.000000  563.000000  563.000000  563.000000
# mean     0.397890    1.215872    2.814781   38.712572    0.007055
# std      0.259357    0.553964    1.893704   39.368369    0.003013
# min      0.111500    0.360200    0.757000    6.802000    0.001713
# 25%      0.232050    0.830500    1.599500   17.830000    0.005190
# 50%      0.319800    1.095000    2.281000   24.320000    0.006399
# 75%      0.473500    1.473500    3.292000   44.690000    0.008182
# max      2.873000    4.885000   21.980000  525.600000    0.031130
#
#        compactness   concavity  concave points    symmetry  fractal_dimension
# count   563.000000  563.000000      563.000000  563.000000         563.000000
# mean      0.025415    0.031823        0.011773    0.020596           0.003802
# std       0.017944    0.030269        0.006171    0.008283           0.002658
# ...

# %%
plt.figure(figsize=(20,20))
plt.subplot(5,2,1)
sns.violinplot(x=se_df["radius"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,2)
sns.violinplot(x=se_df["texture"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,3)
sns.violinplot(x=se_df["perimeter"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,4)
sns.violinplot(x=se_df["area"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,5)
sns.violinplot(x=se_df["smoothness"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,6)
sns.violinplot(x=se_df["compactness"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,7)
sns.violinplot(x=se_df["concavity"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,8)
sns.violinplot(x=se_df["concave points"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,9)
sns.violinplot(x=se_df["symmetry"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,10)
sns.violinplot(x=se_df["fractal_dimension"])

# %% [markdown]
# #### there are to much outliers but if we drop all of them the data will disapear

# %%
worst_df =data.iloc[:, 21:]
#drop the _worst
worst_df.rename(columns=lambda x: x[:-6], inplace=True)
worst_df.head()
# Out:
#    radius  texture  perimeter    area  smoothness  compactness  concavity  \
# 0   25.38    17.33     184.60  2019.0      0.1622       0.6656     0.7119
# 1   24.99    23.41     158.80  1956.0      0.1238       0.1866     0.2416
# 2   23.57    25.53     152.50  1709.0      0.1444       0.4245     0.4504
# 3   14.91    26.50      98.87   567.7      0.2098       0.8663     0.6869
# 4   22.54    16.67     152.20  1575.0      0.1374       0.2050     0.4000
#
#    concave points  symmetry  fractal_dimension
# 0          0.2654    0.4601            0.11890
# 1          0.1860    0.2750            0.08902
# 2          0.2430    0.3613            0.08758
# 3          0.2575    0.6638            0.17300
# 4          0.1625    0.2364            0.07678

# %%
worst_df.describe()
# Out:
#            radius     texture   perimeter         area  smoothness  \
# count  563.000000  563.000000  563.000000   563.000000  563.000000
# mean    16.120780   25.542504  106.234156   858.621314    0.132172
# std      4.600356    5.956283   31.991264   520.745298    0.022801
# min      7.930000   12.020000   50.410000   185.200000    0.071170
# 25%     12.995000   21.045000   84.035000   513.950000    0.116400
# 50%     14.910000   25.340000   97.580000   683.400000    0.131200
# 75%     18.530000   29.445000  124.200000  1038.000000    0.146000
# max     31.010000   44.870000  211.700000  3143.000000    0.222600
#
#        compactness   concavity  concave points    symmetry  fractal_dimension
# count   563.000000  563.000000      563.000000  563.000000         563.000000
# mean      0.252262    0.269447        0.113453    0.289920           0.083914
# std       0.156565    0.207641        0.064931    0.062039           0.018083
# ...

# %%
plt.figure(figsize=(20,20))
plt.subplot(5,2,1)
sns.violinplot(x=worst_df["radius"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,2)
sns.violinplot(x=worst_df["texture"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,3)
sns.violinplot(x=worst_df["perimeter"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,4)
sns.violinplot(x=worst_df["area"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,5)
sns.violinplot(x=worst_df["smoothness"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,6)
sns.violinplot(x=worst_df["compactness"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,7)
sns.violinplot(x=worst_df["concavity"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,8)
sns.violinplot(x=worst_df["concave points"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,9)
sns.violinplot(x=worst_df["symmetry"])
plt.figure(figsize=(20,20))
plt.subplot(5,2,10)
sns.violinplot(x=worst_df["fractal_dimension"])
